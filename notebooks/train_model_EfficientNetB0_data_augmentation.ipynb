# %%
import numpy as np

import tensorflow as tf

from keras.models import Model
from keras.layers import Dense, Input, GlobalAveragePooling2D

from tensorflow.keras.preprocessing import image

from keras_efficientnets import EfficientNetB0

from PIL import Image
import os

from keras.callbacks import EarlyStopping

from keras.callbacks import LearningRateScheduler
import keras.backend as K

from sklearn.preprocessing import LabelBinarizer

import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# définition des paramètres personalisés

# personal layers for VGG16 models
n_classes = 7
n_layers = 7
n_neurons_BeforeLast = 128
f_activation = 'relu'
f_activation_lastLayer = 'softmax'

# personal parameters for compilation
optimizer = 'Adagrad'
loss = 'categorical_crossentropy'

# personnal parameters for training (fitness)
epochs = 100
batch_size = 32

# personal parameters for datagen
len_heig = 224

#numéro de l'essai
num_essai = '0_efficientNet_data_augmentation'

file_name = (str(num_essai) + '_' + str(n_classes) + '_' + str(n_layers) +
'_' + str(n_neurons_BeforeLast) + '_' + str(f_activation) +
'_' + str(f_activation_lastLayer) + '_' + str(optimizer) +
'_' + str(loss) + '_' + str(epochs) + '_' + str(batch_size) )

# %%
# Création du générateur d'images avec augmentation
datagen = ImageDataGenerator(
    rescale=1./255,  # Normalisation des valeurs des pixels entre 0 et 1
    rotation_range=0,  # Rotation aléatoire jusqu'à 40 degrés
    width_shift_range=0,  # Décalage horizontal aléatoire jusqu'à 20% de la largeur de l'image
    height_shift_range=0,  # Décalage vertical aléatoire jusqu'à 20% de la hauteur de l'image
    shear_range=0,  # Cisaillement aléatoire jusqu'à 20%
    zoom_range=0,  # Zoom aléatoire entre 80% et 120% de l'échelle originale
    horizontal_flip=False,  # Retournement horizontal aléatoire
    fill_mode='nearest',  # Stratégie de remplissage des nouveaux pixels
    validation_split=0.2  # Split pour validation
)

# %%
# Création des générateurs de données d'entraînement et de validation
train_generator = datagen.flow_from_directory(
    '../img_prepa',
    target_size=(len_heig, len_heig),
    batch_size=batch_size,
    class_mode='categorical',  # ou 'binary'
    subset='training'
)
# Out:
# Found 4480 images belonging to 7 classes.

# %%
validation_generator = datagen.flow_from_directory(
    '../img_prepa',
    target_size=(len_heig, len_heig),
    batch_size=batch_size,
    class_mode='categorical',  # ou 'binary'
    subset='validation'
)
# Out:
# Found 1120 images belonging to 7 classes.

# %%
# Model EfficientNetB0 loading without fully connected layers

input_shape = (len_heig, len_heig, 3)  # Spécifiez la taille de l'entrée
input_tensor = Input(shape=input_shape)
base_model = EfficientNetB0(input_tensor=input_tensor, include_top=False, weights='imagenet')#, classes=1000)

# %%
# Freeze convolution layers to avoid training
for layer in base_model.layers:
    layer.trainable = False

# %%
# Add personnal layers for training
x = base_model.output

x = GlobalAveragePooling2D()(x)

for i in range(n_layers):
    x = Dense(n_neurons_BeforeLast * (n_classes-i), activation=f_activation)(x) #personal layer


predictions = Dense(n_classes, activation=f_activation_lastLayer)(x)

# %%
# generate model VGG16 with personal fully connected layers
model = Model(inputs=base_model.input, outputs=predictions)

# %%
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# %%
# def scheduler(epoch, lr):
#     if epoch < 5:
#         return lr
#     else:
#         return lr * K.exp(-0.1)

# lr_scheduler = LearningRateScheduler(scheduler)

# %%
# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# %%
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=epochs,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 140/140 [==============================] - 30s 86ms/step - loss: 1.9384 - accuracy: 0.1779 - val_loss: 1.9220 - val_accuracy: 0.2482
# Epoch 2/100
# 140/140 [==============================] - 11s 75ms/step - loss: 1.9008 - accuracy: 0.2969 - val_loss: 1.8760 - val_accuracy: 0.3598
# Epoch 3/100
# 140/140 [==============================] - 10s 72ms/step - loss: 1.8330 - accuracy: 0.3960 - val_loss: 1.7832 - val_accuracy: 0.4313
# Epoch 4/100
# 140/140 [==============================] - 10s 73ms/step - loss: 1.6904 - accuracy: 0.4685 - val_loss: 1.5934 - val_accuracy: 0.5116
# Epoch 5/100
# 140/140 [==============================] - 10s 73ms/step - loss: 1.4498 - accuracy: 0.5395 - val_loss: 1.3413 - val_accuracy: 0.5205
# Epoch 6/100
# 140/140 [==============================] - 10s 71ms/step - loss: 1.2036 - accuracy: 0.6056 - val_loss: 1.1290 - val_accuracy: 0.6009
# Epoch 7/100
# 140/140 [==============================] - 10s 72ms/step - loss: 1.0074 - accuracy: 0.6598 - val_loss: 0.9536 - val_accuracy: 0.6723
# Epoch 8/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.8607 - accuracy: 0.7138 - val_loss: 0.8517 - val_accuracy: 0.6911
# Epoch 9/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.7625 - accuracy: 0.7382 - val_loss: 0.7627 - val_accuracy: 0.7232
# Epoch 10/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.6806 - accuracy: 0.7656 - val_loss: 0.7129 - val_accuracy: 0.7437
# Epoch 11/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.6186 - accuracy: 0.7882 - val_loss: 0.6597 - val_accuracy: 0.7607
# Epoch 12/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.5655 - accuracy: 0.8109 - val_loss: 0.6179 - val_accuracy: 0.7777
# Epoch 13/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.5163 - accuracy: 0.8275 - val_loss: 0.5569 - val_accuracy: 0.8009
# Epoch 14/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.4772 - accuracy: 0.8368 - val_loss: 0.5408 - val_accuracy: 0.7991
# Epoch 15/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.4458 - accuracy: 0.8536 - val_loss: 0.4952 - val_accuracy: 0.8134
# Epoch 16/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.4092 - accuracy: 0.8596 - val_loss: 0.4836 - val_accuracy: 0.8366
# Epoch 17/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.3846 - accuracy: 0.8750 - val_loss: 0.4473 - val_accuracy: 0.8393
# Epoch 18/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.3575 - accuracy: 0.8835 - val_loss: 0.4238 - val_accuracy: 0.8527
# Epoch 19/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.3352 - accuracy: 0.8900 - val_loss: 0.4218 - val_accuracy: 0.8625
# Epoch 20/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.3144 - accuracy: 0.8982 - val_loss: 0.4181 - val_accuracy: 0.8473
# Epoch 21/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.3010 - accuracy: 0.8998 - val_loss: 0.3869 - val_accuracy: 0.8634
# Epoch 22/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.2818 - accuracy: 0.9076 - val_loss: 0.3860 - val_accuracy: 0.8589
# Epoch 23/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.2698 - accuracy: 0.9121 - val_loss: 0.3686 - val_accuracy: 0.8687
# Epoch 24/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.2547 - accuracy: 0.9158 - val_loss: 0.3591 - val_accuracy: 0.8705
# Epoch 25/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.2392 - accuracy: 0.9239 - val_loss: 0.3618 - val_accuracy: 0.8750
# Epoch 26/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.2297 - accuracy: 0.9259 - val_loss: 0.4084 - val_accuracy: 0.8446
# Epoch 27/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.2213 - accuracy: 0.9310 - val_loss: 0.3237 - val_accuracy: 0.8848
# Epoch 28/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.2125 - accuracy: 0.9319 - val_loss: 0.3518 - val_accuracy: 0.8625
# Epoch 29/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.2000 - accuracy: 0.9339 - val_loss: 0.3230 - val_accuracy: 0.8875
# Epoch 30/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.1917 - accuracy: 0.9395 - val_loss: 0.3616 - val_accuracy: 0.8643
# Epoch 31/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.1824 - accuracy: 0.9411 - val_loss: 0.3138 - val_accuracy: 0.8911
# Epoch 32/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.1714 - accuracy: 0.9484 - val_loss: 0.3131 - val_accuracy: 0.8857
# Epoch 33/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.1675 - accuracy: 0.9504 - val_loss: 0.3011 - val_accuracy: 0.8911
# Epoch 34/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.1584 - accuracy: 0.9531 - val_loss: 0.3570 - val_accuracy: 0.8643
# Epoch 35/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.1531 - accuracy: 0.9522 - val_loss: 0.3197 - val_accuracy: 0.8777
# Epoch 36/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.1457 - accuracy: 0.9556 - val_loss: 0.2915 - val_accuracy: 0.8964
# Epoch 37/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.1408 - accuracy: 0.9623 - val_loss: 0.3025 - val_accuracy: 0.8991
# Epoch 38/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.1321 - accuracy: 0.9638 - val_loss: 0.2793 - val_accuracy: 0.9045
# Epoch 39/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.1270 - accuracy: 0.9652 - val_loss: 0.2793 - val_accuracy: 0.9018
# Epoch 40/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.1212 - accuracy: 0.9681 - val_loss: 0.2705 - val_accuracy: 0.9107
# Epoch 41/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.1192 - accuracy: 0.9670 - val_loss: 0.2736 - val_accuracy: 0.9089
# Epoch 42/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.1103 - accuracy: 0.9721 - val_loss: 0.2634 - val_accuracy: 0.9098
# Epoch 43/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.1074 - accuracy: 0.9739 - val_loss: 0.2821 - val_accuracy: 0.9045
# Epoch 44/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.1036 - accuracy: 0.9757 - val_loss: 0.2651 - val_accuracy: 0.9107
# Epoch 45/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.0976 - accuracy: 0.9786 - val_loss: 0.2851 - val_accuracy: 0.9107

# %%
# Model training
# model.fit(train_generator, epochs= epochs, batch_size= batch_size, validation_data=validation_generator, callbacks=[early_stopping])#, lr_scheduler

# %%
model.save(f"../model_saved/{num_essai}_model.h5py")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 81). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../model_saved/0_efficientNet_data_augmentation_model.h5py\assets
# INFO:tensorflow:Assets written to: ../model_saved/0_efficientNet_data_augmentation_model.h5py\assets
# c:\Users\dimle\Documents\clone_repo\lego_classification\.conda\lib\site-packages\keras\engine\functional.py:1384: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# c:\Users\dimle\Documents\clone_repo\lego_classification\.conda\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
